# %% [markdown]
# This is the notebook for the first afternoon session. It does what the morning session does.

# %%
import numpy as np
import matplotlib.pyplot as plt
# import seaborn

# %% [markdown]
# Make some data

# %%
xs = np.linspace(-10, 10)
ys = np.sin(xs) / xs

# %% [markdown]
# Do some viz

# %%
plt.plot(xs, ys)
